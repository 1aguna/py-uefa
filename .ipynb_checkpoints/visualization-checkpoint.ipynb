# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import altair as alt
import seaborn as sns

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)
# Out:
# <ipython-input-14-1390d13c0cdd>:4: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# # Loading Data

# %%
source = pd.read_csv("premierleague1819/epl_1819_no_comma.csv")
display(source)
# Out:
#                  Team                        category  \
# 0   Manchester City    Champions League
# 1   Liverpool          Champions League
# 2   Chelsea            Champions League Qualification
# 3   Tottenham          Champions League Qualification
# 4   Arsenal            Europa League
# 5   Manchester United  Europa League
# 6   Wolverhampton      Europa League Qualification
# 7   Everton            No UEFA Competitions
# 8   Leicester          No UEFA Competitions
# 9   West Ham           No UEFA Competitions
# 10  Watford            No UEFA Competitions
# 11  Crystal Palace     No UEFA Competitions
# 12  Newcastle          No UEFA Competitions
# 13   Bournemouth       No UEFA Competitions
# 14  Burnley            No UEFA Competitions
# 15  Southampton        No UEFA Competitions
# 16  Brighton           No UEFA Competitions
# 17  Cardiff            Relegated
# 18  Fulham             Relegated
# 19  Huddersfield       Relegated
#
# ...

# %%
brush = alt.selection(type='interval')

points = alt.Chart(source).mark_point().encode(
    x='attack_crosses',
    y='attack_scored',
    color=alt.condition(brush, 'Team', alt.value('lightgray'))
).add_selection(
    brush
)

bars = alt.Chart(source).mark_bar().encode(
    y='Team',
    color='Team',
    x='general_points'
).transform_filter(
    brush
)

points & bars
# Out:
# alt.VConcatChart(...)

# %%
cols = ["attack_passes", "attack_passes_through", "attack_passes_long", "attack_passes_back", "attack_crosses", "attack_corners_taken"]
pp = sns.pairplot(source[cols], size=1.8, aspect=1.8,
                  plot_kws=dict(edgecolor="k", linewidth=0.5),
                  diag_kind="kde", diag_kws=dict(shade=True))

fig = pp.fig 
fig.subplots_adjust(top=0.93, wspace=0.3)
t = fig.suptitle('Attack Stats Pairwise', fontsize=14)
# Out:
# /Users/laguna/opt/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:2071: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
